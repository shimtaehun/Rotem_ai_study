# %% [markdown]
# ## Sigmoid는 Softmax로 처리 가능

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
dataset = np.loadtxt('https://raw.githubusercontent.com/pykwon/python/refs/heads/master/testdata_utf8/diabetes.csv', delimiter=',')
print(dataset.shape)
print(dataset[:1])
print(set(dataset[:, -1]))
# Out:
# (759, 9)
# [[-0.294118    0.487437    0.180328   -0.292929    0.          0.00149028
#   -0.53117    -0.0333333   0.        ]]
# {0.0, 1.0}

# %% [markdown]
# ## 이항분류

# %%
from tabnanny import verbose
from sklearn import metrics


x_train, x_test, y_train, y_test = train_test_split(dataset[:, 0:8],dataset[:, -1], test_size=0.3, shuffle=True, random_state=133)
print(x_train.shape, x_test.shape)  # (531, 8) (228, 8)

model = Sequential()
model.add((Input(shape=(8,))))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
print(model.summary())

model.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=0)
scores = model.evaluate(x_test, y_test)
print('%s : %.2f%%'%(model.metrics_names[1], scores[1] * 100))
# Out:
# (531, 8) (228, 8)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                576
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,689
# Trainable params: 2,689
# Non-trainable params: 0
# _________________________________________________________________
# None
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5568 - accuracy: 0.7325
# accuracy : 73.25%

# %% [markdown]
# ## 다항분류

# %%
# one_hot처리
x_train, x_test, y_train, y_test = train_test_split(dataset[:, 0:8],dataset[:, -1], test_size=0.3, shuffle=True, random_state=133)

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)     

model2 = Sequential()
model2.add((Input(shape=(8,))))
model2.add(Dense(64, activation='relu'))
model2.add(Dense(32, activation='relu'))
model2.add(Dense(2, activation='softmax'))

model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())

model2.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=0)
scores = model2.evaluate(x_test, y_test)
print('%s : %.2f%%'%(model2.metrics_names[1], scores[1] * 100))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                576
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,689
# Trainable params: 2,689
# Non-trainable params: 0
# _________________________________________________________________
# None
# 8/8 [==============================] - 0s 985us/step - loss: 0.5644 - accuracy: 0.7105
# accuracy : 71.05%
